# %%
import pandas as pd
import os
import openpyxl

# %%
caminho = os.path.abspath(r"\\10.1.0.4\dados\DADOS\INADIMPLENCIA\BASE\Contas a Receber em aberto - GS.xlsx")

# %%
workbook = openpyxl.load_workbook(caminho, data_only=True)
sheet = workbook['Consolidado']
sheet.cell(row=2, column=21).value

# %%
sheet = workbook['Consolidado']

# %%
sheet.cell(row=2, column=21).value
# Out:
# str

# %%
os.path.exists(caminho)
# Out:
# True

# %%
planilha = pd.read_excel(caminho)

# %%
datetime.strftime(planilha['Atualizacao_planilha'][0], '%d/%m/%Y %H:%M:%S')
# Out:
# '04/07/2025 13:39:34'

# %%
timestamp('31/07/2025 14:47:38')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 timestamp('31/07/2025 14:47:38')
#
# NameError: name 'timestamp' is not defined

# %%
from datetime import datetime

# %%
planilha
# Out:
#       CODIGO_EMPRESA                                   Empresa  \
# 0                  2                           0002 - CONDONAL
# 1                  2                           0002 - CONDONAL
# 2                  2                           0002 - CONDONAL
# 3                  2                           0002 - CONDONAL
# 4                  2                           0002 - CONDONAL
# ...              ...                                       ...
# 5641              25  0025 - CONDONAL BASE ANTERIOR - CONSULTA
# 5642              25  0025 - CONDONAL BASE ANTERIOR - CONSULTA
# 5643              25  0025 - CONDONAL BASE ANTERIOR - CONSULTA
# 5644              25  0025 - CONDONAL BASE ANTERIOR - CONSULTA
# 5645              25  0025 - CONDONAL BASE ANTERIOR - CONSULTA
#
#                                         Estabelecimento  \
# 0              0009 - CONDONAL COMERCIO E SERVICOS LTDA
# 1              0006 - CONDO LOCACAO DE MAO DE OBRA LTDA
# ...

# %%
planilha['Atualizacao_planilha'][0].date()
# Out:
# datetime.date(2025, 7, 4)

# %%
datetime.now().date()
# Out:
# datetime.date(2025, 7, 31)

# %%
planilha
# Out:
#       CODIGO_EMPRESA                                   Empresa  \
# 0                  2                           0002 - CONDONAL
# 1                  2                           0002 - CONDONAL
# 2                  2                           0002 - CONDONAL
# 3                  2                           0002 - CONDONAL
# 4                  2                           0002 - CONDONAL
# ...              ...                                       ...
# 5641              25  0025 - CONDONAL BASE ANTERIOR - CONSULTA
# 5642              25  0025 - CONDONAL BASE ANTERIOR - CONSULTA
# 5643              25  0025 - CONDONAL BASE ANTERIOR - CONSULTA
# 5644              25  0025 - CONDONAL BASE ANTERIOR - CONSULTA
# 5645              25  0025 - CONDONAL BASE ANTERIOR - CONSULTA
#
#                                         Estabelecimento  \
# 0              0009 - CONDONAL COMERCIO E SERVICOS LTDA
# 1              0006 - CONDO LOCACAO DE MAO DE OBRA LTDA
# ...

# %%
planilha = pd.read_excel(r"teste.xlsx", dtype=str)

# %%
planilha
# Out:
#   Atualizacao planilha
# 0  2025-07-31 14:47:38

# %%
type(planilha['Atualizacao planilha'][0])
# Out:
# str
